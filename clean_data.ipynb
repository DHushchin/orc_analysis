# %%
import pandas as pd
import numpy as np

orcs = pd.read_csv('orcs.csv', index_col=0, 
                   usecols=['orc_id', 'age', 'bplace', 'nationality', 'mstatus_cl', 'address', 
                            'reg_address', 'mil_rank_cl', 'edu_lvl_cl', 'pass_auth', 'family'],
                   encoding='utf-8')
orcs['region'] = np.nan
orcs.sort_index(inplace=True)
orcs.head()
# Out:
# d:\Apps\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,9,50) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          age                                             bplace nationality  \
# orc_id
# 1       32.0  Куйбышевская область                  г. Толятти      русский
# 2       33.0  Кировская область, Верхнекамский район, пос. Т...     русский
# 3       28.0  Читинская области Дульдургинский район с. Чинд...      Бурят
# 4       26.0  Приморский край Яковлевский район с.Варфоломеевка     русский
# 5       19.0                      Приморский край,г.Владивосток     русский
#
#                                                   address reg_address  \
# orc_id
# 1       Приморский край г. Владивосток Анны-Щетининой ...         NaN
# 2         Примосркий край, г. Владивосток ул. Снеговая 31         NaN
# 3       Приморский край г.Владивосток ул. Луговая  д. ...         NaN
# 4       Приморский край г.Владивосток          ул. Саф...         NaN
# 5          Примосркий край г.Владивосток ул.Снеговая д.31         NaN
#
#                                                 pass_auth  \
# orc_id
# 1                                                     NaN
# 2       ТП в пос.Рудничный УФМС России по Кировской об...
# 3       ТП УФМС России по Забайкальскому краю в Дульду...
# 4       УФМС России по Приморскому краю в Яковлевском ...
# 5                                                     NaN
#
#                                                    family mstatus_cl  \
# orc_id
# 1       Жена: Ендовицкая Анастасия Викторовна \n19.04....      Женат
# 2       Мать: Кравцова Наталья Анатольевна\n05.12.1964...     Холост
# 3       Мать: Дулмажапова Татьяяна Тумендоржиевна \n14...     Холост
# 4       Мать: Киргизова Ольга Юрьевна \n15.09.1975г.р....     Холост
# 5       Мать: Леорда Наталья Александровна\n25.10.1980...     Холост
#
#             edu_lvl_cl      mil_rank_cl  region
# orc_id
# 1               Высшее              NaN     NaN
# 2       Среднее полное  Старший Сержант     NaN
# 3       Среднее полное  Младший Сержант     NaN
# 4       Среднее полное           Матрос     NaN
# 5              Среднее           Матрос     NaN

# %%
orcs.dropna(subset=['mil_rank_cl', 'age'], inplace=True)
orcs.age = orcs.age.astype(int)
orcs.head()
# Out:
#         age                                             bplace nationality  \
# orc_id
# 2        33  Кировская область, Верхнекамский район, пос. Т...     русский
# 3        28  Читинская области Дульдургинский район с. Чинд...      Бурят
# 4        26  Приморский край Яковлевский район с.Варфоломеевка     русский
# 5        19                      Приморский край,г.Владивосток     русский
# 8        36        Томская область Асиновский район с. Казанка     русский
#
#                                                   address reg_address  \
# orc_id
# 2         Примосркий край, г. Владивосток ул. Снеговая 31         NaN
# 3       Приморский край г.Владивосток ул. Луговая  д. ...         NaN
# 4       Приморский край г.Владивосток          ул. Саф...         NaN
# 5          Примосркий край г.Владивосток ул.Снеговая д.31         NaN
# 8       Приморский край г. Владивосток Адмирала Горшко...         NaN
#
#                                                 pass_auth  \
# orc_id
# 2       ТП в пос.Рудничный УФМС России по Кировской об...
# 3       ТП УФМС России по Забайкальскому краю в Дульду...
# 4       УФМС России по Приморскому краю в Яковлевском ...
# 5                                                     NaN
# 8                         Асиновским ГОВД Томской области
#
#                                                    family mstatus_cl  \
# orc_id
# 2       Мать: Кравцова Наталья Анатольевна\n05.12.1964...     Холост
# 3       Мать: Дулмажапова Татьяяна Тумендоржиевна \n14...     Холост
# 4       Мать: Киргизова Ольга Юрьевна \n15.09.1975г.р....     Холост
# 5       Мать: Леорда Наталья Александровна\n25.10.1980...     Холост
# 8       Жена: Коновалова Василия Васильевна\n29.12.198...      Женат
#
#                  edu_lvl_cl      mil_rank_cl  region
# orc_id
# 2            Среднее полное  Старший Сержант     NaN
# 3            Среднее полное  Младший Сержант     NaN
# 4            Среднее полное           Матрос     NaN
# 5                   Среднее           Матрос     NaN
# 8       Среднее техническое        Прапорщик     NaN

# %%
orcs.isna().sum()
# Out:
# age                0
# bplace         67061
# nationality    67065
# address        67371
# reg_address    67142
# pass_auth       3780
# family         67066
# mstatus_cl     66749
# edu_lvl_cl     67054
# mil_rank_cl        0
# region         67443
# dtype: int64

# %%
areas = \
['Республика Адыгея', 
'Республика Башкортостан', 
'Республика Бурятия', 
'Республика Алтай', 
'Республика Дагестан', 
'Республика Ингушетия', 
'Кабардино-Балкарская Республика', 
'Республика Калмыкия', 
'Карачаево-Черкесская Республика', 
'Республика Карелия', 
'Республика Коми', 
'Республика Марий Эл', 
'Республика Мордовия', 
'Республика Саха (Якутия)', 
'Республика Северная Осетия', 
'Республика Татарстан', 
'Республика Тыва', 
'Удмуртская Республика', 
'Республика Хакасия', 
'Чеченская Республика', 
'Чувашская Республика - Чувашия', 
'Алтайский край', 
'Краснодарский край', 
'Красноярский край', 
'Приморский край', 
'Ставропольский край', 
'Хабаровский край', 
'Амурская область', 
'Архангельская область', 
'Астраханская область', 
'Белгородская область', 
'Брянская область', 
'Владимирская область', 
'Волгоградская область', 
'Вологодская область', 
'Воронежская область', 
'Ивановская область', 
'Иркутская область', 
'Калининградская область', 
'Калужская область', 
'Камчатский край', 
'Кемеровская область', 
'Кировская область', 
'Костромская область', 
'Курганская область', 
'Курская область', 
'Ленинградская область', 
'Липецкая область', 
'Магаданская область', 
'Московская область', 
'Мурманская область', 
'Нижегородская область', 
'Новгородская область', 
'Новосибирская область', 
'Омская область', 
'Оренбургская область', 
'Орловская область', 
'Пензенская область', 
'Пермский край', 
'Псковская область', 
'Ростовская область', 
'Рязанская область', 
'Самарская область', 
'Саратовская область', 
'Сахалинская область', 
'Свердловская область', 
'Смоленская область', 
'Тамбовская область', 
'Тверская область', 
'Томская область', 
'Тульская область', 
'Тюменская область', 
'Ульяновская область', 
'Челябинская область', 
'Забайкальский край', 
'Ярославская область', 
'Москва', 
'Санкт-Петербург', 
'Еврейская автономная область', 
'Ненецкий автономный округ', 
'Ханты-Мансийский автономный округ', 
'Чукотский автономный округ', 
'Ямало-Ненецкий автономный округ'
]

# %%
from fuzzywuzzy import fuzz

for i in orcs.index:
    try:
        # clear region
        if not pd.isna(orcs['bplace'][i]):
            orcs.loc[i, 'region'] =  orcs.loc[i, 'bplace']
        else:
            if not pd.isna(orcs['reg_address'][i]):
                orcs.loc[i, 'region'] =  orcs.loc[i, 'reg_address']
            else:
                if not pd.isna(orcs['address'][i]):
                    orcs.loc[i, 'region'] =  orcs.loc[i, 'address']
                else:
                    if not pd.isna(orcs['pass_auth'][i]):
                        orcs.loc[i, 'region'] =  orcs.loc[i, 'pass_auth'] 
         
        # clear family               
        if not pd.isna(orcs['family'][i]):
            orcs.loc[i, 'family'] =  True
        else:
            if orcs['mstatus_cl'][i] in ['Женат', 'Замужем']:
                orcs.loc[i, 'family'] =  True
            else:
                orcs.loc[i, 'family'] = False
                
        # clear education
        if pd.isna(orcs['edu_lvl_cl'][i]):
            orcs.loc[i, 'edu_lvl_cl'] =  'среднее'
        else:
            if orcs['edu_lvl_cl'][i] in ['ВВУЗ', 'ВУЦ']:
                orcs.loc[i, 'edu_lvl_cl'] = 'высшее военное'
            if orcs['edu_lvl_cl'][i] == 'Высшее':
                orcs.loc[i, 'edu_lvl_cl'] = 'высшее невоенное'
            else:
                orcs.loc[i, 'edu_lvl_cl'] = 'среднее'
        
        # clear region        
        ratios = {j: fuzz.token_set_ratio(orcs['region'][i], areas[j]) for j in range(len(areas))}
        orcs.loc[i, 'region'] = areas[max(ratios, key=ratios.get)]  
    except:
        pass


#clear nationality  
orcs.nationality = orcs.nationality.apply(lambda x: 'русский' if pd.isna(x) else x.lower()) 

orcs.drop(['bplace', 'reg_address', 'address', 'pass_auth', 'mstatus_cl'], axis=1, inplace=True)
orcs.to_csv('orcs_cleaned.csv', encoding='utf-8')
orcs.isna().sum()
# Out:
# d:\Apps\Anaconda\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# age            0
# nationality    0
# family         0
# edu_lvl_cl     0
# mil_rank_cl    0
# region         0
# dtype: int64

# %%
orcs.mil_rank_cl.value_counts()
# Out:
# Рядовой                         14940
# Сержант                          9640
# Младший Сержант                  6965
# Ефрейтор                         6769
# Матрос                           3141
# Майор                            3127
# Прапорщик                        3096
# Старший Прапорщик                3002
# Капитан                          2819
# Старший Сержант                  2433
# Подполковник                     1938
# Старший Матрос                   1742
# Лейтенант                        1343
# Старший Лейтенант                1180
# Мичман                            739
# Старшина                          708
# Старший Мичман                    700
# Старшина 2 статьи                 488
# Капитан 3 ранга                   463
# Капитан 2 ранга                   460
# Полковник                         457
# Старшина 1 статьи                 432
# Главный Старшина                  324
# Капитан-лейтенант                 206
# Капитан 1 ранга                   151
# Главный корабельный старшина       95
# Старшина Сержант                   46
# Генерал-майор                      28
# Контр-адмирал                      10
# Старший Офицер                      1
# Name: mil_rank_cl, dtype: int64
